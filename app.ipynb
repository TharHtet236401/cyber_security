# %%
import pandas as pd

# %%
df = pd.read_csv("data_sets/world_happiness_report.csv")

# %%
df.head()
# Out:
#    Unnamed: 0      Country          Region  Happiness Rank  Happiness Score  \
# 0           0  Switzerland  Western Europe             1.0            7.587
# 1           1      Iceland  Western Europe             2.0            7.561
# 2           2      Denmark  Western Europe             3.0            7.527
# 3           3       Norway  Western Europe             4.0            7.522
# 4           4       Canada   North America             5.0            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# ...

# %%
df.sort_values(by='year', ascending=False)
# Out:
#       Unnamed: 0      Country                           Region  \
# 1230        1230           xx                              NaN
# 1138        1138     Honduras                              NaN
# 1136        1136   Uzbekistan                              NaN
# 1135        1135    Mauritius                              NaN
# 1134        1134      Hungary                              NaN
# ...          ...          ...                              ...
# 105          105   Tajikistan       Central and Eastern Europe
# 104          104     Honduras      Latin America and Caribbean
# 103          103      Hungary       Central and Eastern Europe
# 102          102      Lebanon  Middle East and Northern Africa
# 0              0  Switzerland                   Western Europe
#
#       Happiness Rank  Happiness Score  Standard Error  \
# 1230             NaN              NaN             NaN
# 1138             NaN              NaN             NaN
# ...

# %%
df['year'].value_counts()
# Out:
# year
# 2015    158
# 2016    157
# 2018    156
# 2019    156
# 2017    155
# 2020    153
# 2021    149
# 2022    147
# Name: count, dtype: int64

# %%
df['year'].describe()
# Out:
# count    1231.000000
# mean     2018.450041
# std         2.284034
# min      2015.000000
# 25%      2016.000000
# 50%      2018.000000
# 75%      2020.000000
# max      2022.000000
# Name: year, dtype: float64
