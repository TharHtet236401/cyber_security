# %%
import pandas as pd

# %%
df = pd.read_csv("data_sets/Global_Cybersecurity_Threats_2015-2024.csv")

# %%
df.head()
# Out:
#    Country  Year        Attack Type     Target Industry  \
# 0    China  2019           Phishing           Education
# 1    China  2019         Ransomware              Retail
# 2    India  2017  Man-in-the-Middle                  IT
# 3       UK  2024         Ransomware  Telecommunications
# 4  Germany  2018  Man-in-the-Middle                  IT
#
#    Financial Loss (in Million $)  Number of Affected Users Attack Source  \
# 0                          80.53                    773169  Hacker Group
# 1                          62.19                    295961  Hacker Group
# 2                          38.65                    605895  Hacker Group
# 3                          41.44                    659320  Nation-state
# 4                          74.41                    810682       Insider
#
#   Security Vulnerability Type Defense Mechanism Used  \
# 0          Unpatched Software                    VPN
# 1          Unpatched Software               Firewall
# ...

# %%
df.columns
# Out:
# Index(['Country', 'Year', 'Attack Type', 'Target Industry',
#        'Financial Loss (in Million $)', 'Number of Affected Users',
#        'Attack Source', 'Security Vulnerability Type',
#        'Defense Mechanism Used', 'Incident Resolution Time (in Hours)'],
#       dtype='object')

# %%
df.groupby('Attack Source').size().sort_values(ascending=False)
# Out:
# Attack Source
# Nation-state    794
# Unknown         768
# Insider         752
# Hacker Group    686
# dtype: int64

# %%
df['year'].value_counts()
# Out:
# year
# 2015    158
# 2016    157
# 2018    156
# 2019    156
# 2017    155
# 2020    153
# 2021    149
# 2022    147
# Name: count, dtype: int64

# %%
df['year'].describe()
# Out:
# count    1231.000000
# mean     2018.450041
# std         2.284034
# min      2015.000000
# 25%      2016.000000
# 50%      2018.000000
# 75%      2020.000000
# max      2022.000000
# Name: year, dtype: float64

# %%
df['Country'].value_counts()
# Out:
# Country
# UK           321
# Brazil       310
# India        308
# France       305
# Japan        305
# Australia    297
# Russia       295
# Germany      291
# USA          287
# China        281
# Name: count, dtype: int64

# %%
country_data = {
    "UK": {"value": 321, "lat": 55.3781, "lon": -3.4360},
    "Brazil": {"value": 310, "lat": -14.2350, "lon": -51.9253},
    "India": {"value": 308, "lat": 20.5937, "lon": 78.9629},
    "France": {"value": 305, "lat": 46.2276, "lon": 2.2137},
    "Japan": {"value": 305, "lat": 36.2048, "lon": 138.2529},
    "Australia": {"value": 297, "lat": -25.2744, "lon": 133.7751},
    "Russia": {"value": 295, "lat": 61.5240, "lon": 105.3188},
    "Germany": {"value": 291, "lat": 51.1657, "lon": 10.4515},
    "USA": {"value": 287, "lat": 37.0902, "lon": -95.7129},
    "China": {"value": 281, "lat": 35.8617, "lon": 104.1954},
}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 14
#       1 country_data = {
#       2     "UK": {"value": 321, "lat": 55.3781, "lon": -3.4360},
#       3     "Brazil": {"value": 310, "lat": -14.2350, "lon": -51.9253},
#    (...)
#      11     "China": {"value": 281, "lat": 35.8617, "lon": 104.1954},
#      12 }
# ---> 14 df['lat'] = df['Country'].map(country_data.get("lat"))
#
# File c:\Users\Thar_Htet\anaconda3\Lib\site-packages\pandas\core\series.py:4700, in Series.map(self, arg, na_action)
#    4620 def map(
#    4621     self,
#    4622     arg: Callable | Mapping | Series,
#    4623     na_action: Literal["ignore"] | None = None,
#    4624 ) -> Series:
#    4625     """
#    4626     Map values of Series according to an input mapping or function.
#    4627
#    (...)
#    4698     dtype: object
#    4699     """
# ...

# %%
df["lat"] = df["Country"].map(lambda x: country_data[x]["lat"])
df["lon"] = df["Country"].map(lambda x: country_data[x]["lon"])
df["value"] = df["Country"].map(lambda x: country_data[x]["value"])

# %%
df.columns
# Out:
# Index(['Country', 'Year', 'Attack Type', 'Target Industry',
#        'Financial Loss (in Million $)', 'Number of Affected Users',
#        'Attack Source', 'Security Vulnerability Type',
#        'Defense Mechanism Used', 'Incident Resolution Time (in Hours)', 'lat',
#        'lon', 'value'],
#       dtype='object')

# %%
df.head()
# Out:
#    Country  Year        Attack Type     Target Industry  \
# 0    China  2019           Phishing           Education
# 1    China  2019         Ransomware              Retail
# 2    India  2017  Man-in-the-Middle                  IT
# 3       UK  2024         Ransomware  Telecommunications
# 4  Germany  2018  Man-in-the-Middle                  IT
#
#    Financial Loss (in Million $)  Number of Affected Users Attack Source  \
# 0                          80.53                    773169  Hacker Group
# 1                          62.19                    295961  Hacker Group
# 2                          38.65                    605895  Hacker Group
# 3                          41.44                    659320  Nation-state
# 4                          74.41                    810682       Insider
#
#   Security Vulnerability Type Defense Mechanism Used  \
# 0          Unpatched Software                    VPN
# 1          Unpatched Software               Firewall
# ...

# %%
df = df.drop("value", axis=1)

# %%
df.head()
# Out:
#    Country  Year        Attack Type     Target Industry  \
# 0    China  2019           Phishing           Education
# 1    China  2019         Ransomware              Retail
# 2    India  2017  Man-in-the-Middle                  IT
# 3       UK  2024         Ransomware  Telecommunications
# 4  Germany  2018  Man-in-the-Middle                  IT
#
#    Financial Loss (in Million $)  Number of Affected Users Attack Source  \
# 0                          80.53                    773169  Hacker Group
# 1                          62.19                    295961  Hacker Group
# 2                          38.65                    605895  Hacker Group
# 3                          41.44                    659320  Nation-state
# 4                          74.41                    810682       Insider
#
#   Security Vulnerability Type Defense Mechanism Used  \
# 0          Unpatched Software                    VPN
# 1          Unpatched Software               Firewall
# ...

# %%
df.to_csv("g_security_geo.csv", index=False)

# %%
df['Country'].value_counts()
# Out:
# Country
# UK           321
# Brazil       310
# India        308
# France       305
# Japan        305
# Australia    297
# Russia       295
# Germany      291
# USA          287
# China        281
# Name: count, dtype: int64
